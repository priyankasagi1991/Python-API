# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from api_keys import api_key



from citipy import citipy


output_data_file = "cities.csv"


lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
lat_lngs = []
cities = []


lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)


for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
  
    if city not in cities:
        cities.append(city)


len(cities)
# Out:
# 634

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []


record = 1


print(f"Beginning Data Retrieval")
print(f"-------------------------------")


for city in cities:  
    
    
  
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        
        record= record + 1
        
        
        time.sleep(1.01)
        
  
    except:
        print("City not found. Skipping...")
    continue
 
print(f"-------------------------------")
print(f"Data Retrieval Complete")
print(f"-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=hermanus
# Processing Record 2 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=georgetown
# Processing Record 3 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=barrow
# Processing Record 4 | Nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=nabire
# Processing Record 5 | Port Alberni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=port alberni
# Processing Record 6 | Sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=sorland
# Processing Record 7 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=faanui
# Processing Record 8 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=rikitea
# Processing Record 9 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=busselton
# Processing Record 10 | Tucuman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=tucuman
# Processing Record 11 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=ushuaia
# Processing Record 12 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=mahebourg
# Processing Record 13 | Vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=vao
# Processing Record 14 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=mar del plata
# Processing Record 15 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=saskylakh
# Processing Record 16 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=vila velha
# Processing Record 17 | Mackay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=mackay
# Processing Record 18 | Itoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=itoman
# Processing Record 19 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=dikson
# Processing Record 20 | Tiarei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=tiarei
# Processing Record 21 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=carnarvon
# Processing Record 22 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=yellowknife
# Processing Record 23 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=vaini
# Processing Record 24 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=khatanga
# Processing Record 25 | Abu Dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=abu dhabi
# Processing Record 26 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=avarua
# Processing Record 27 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=airai
# Processing Record 28 | Taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=taltal
# City not found. Skipping...
# Processing Record 29 | College
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=college
# City not found. Skipping...
# Processing Record 30 | Kirs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=kirs
# Processing Record 31 | Portree
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=portree
# Processing Record 32 | Machilipatnam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=machilipatnam
# Processing Record 33 | Bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=bandarbeyla
# Processing Record 34 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=hilo
# Processing Record 35 | Sukumo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=sukumo
# Processing Record 36 | Lagos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=lagos
# Processing Record 37 | Nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=nouadhibou
# Processing Record 38 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=bredasdorp
# Processing Record 39 | Yarkovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=yarkovo
# Processing Record 40 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=lebu
# Processing Record 41 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=arraial do cabo
# Processing Record 42 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=mataura
# Processing Record 43 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=puerto ayora
# Processing Record 44 | Rzhev
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=rzhev
# Processing Record 45 | Comodoro Rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=comodoro rivadavia
# Processing Record 46 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=lompoc
# City not found. Skipping...
# Processing Record 47 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=tiksi
# Processing Record 48 | Tezu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=tezu
# Processing Record 49 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=punta arenas
# Processing Record 50 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=tuktoyaktuk
# Processing Record 51 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=los llanos de aridane
# Processing Record 52 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=jamestown
# Processing Record 53 | Storslett
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=storslett
# City not found. Skipping...
# Processing Record 54 | Ponta Pora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=ponta pora
# Processing Record 55 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=new norfolk
# Processing Record 56 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=kruisfontein
# Processing Record 57 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=hithadhoo
# Processing Record 58 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=katsuura
# Processing Record 59 | Talara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=talara
# Processing Record 60 | Vada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=vada
# Processing Record 61 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=torbay
# Processing Record 62 | Omidiyeh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=omidiyeh
# Processing Record 63 | Raduzhnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=raduzhnyy
# Processing Record 64 | Dalvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=dalvik
# Processing Record 65 | Evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=evensk
# Processing Record 66 | Atherton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=atherton
# Processing Record 67 | Henties Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=henties bay
# Processing Record 68 | Kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=kaeo
# Processing Record 69 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=hobart
# Processing Record 70 | Quesnel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=quesnel
# Processing Record 71 | Bukavu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=bukavu
# Processing Record 72 | Vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=vestmannaeyjar
# Processing Record 73 | Saint Simons
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=saint simons
# City not found. Skipping...
# Processing Record 74 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=bluff
# Processing Record 75 | Bundaberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=bundaberg
# Processing Record 76 | Raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=raudeberg
# Processing Record 77 | Port Hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=port hedland
# Processing Record 78 | Ormara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=ormara
# Processing Record 79 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=albany
# Processing Record 80 | Mokrousovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=mokrousovo
# Processing Record 81 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=tasiilaq
# Processing Record 82 | Hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=hofn
# Processing Record 83 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=kodiak
# Processing Record 84 | Colares
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=colares
# Processing Record 85 | Potiskum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=potiskum
# Processing Record 86 | Surgut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=surgut
# Processing Record 87 | Mana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=mana
# Processing Record 88 | Druzhba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=druzhba
# City not found. Skipping...
# Processing Record 89 | Mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=mandalgovi
# Processing Record 90 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=kaitangata
# Processing Record 91 | Mount Isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=mount isa
# Processing Record 92 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=cape town
# Processing Record 93 | Whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=whitehorse
# City not found. Skipping...
# Processing Record 94 | Ust-Tsilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=ust-tsilma
# City not found. Skipping...
# Processing Record 95 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=port alfred
# Processing Record 96 | Susurluk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=susurluk
# Processing Record 97 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=east london
# Processing Record 98 | Socorro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=socorro
# Processing Record 99 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=lagoa
# Processing Record 100 | Yakeshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=yakeshi
# Processing Record 101 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=fairbanks
# Processing Record 102 | Viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=viedma
# Processing Record 103 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=bathsheba
# Processing Record 104 | Gimli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=gimli
# Processing Record 105 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=bambous virieux
# Processing Record 106 | Chegdomyn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=chegdomyn
# Processing Record 107 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=souillac
# Processing Record 108 | Tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=tual
# Processing Record 109 | Chumphon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=chumphon
# Processing Record 110 | Westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=westport
# Processing Record 111 | Alice Springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=alice springs
# Processing Record 112 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=cidreira
# Processing Record 113 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=kavieng
# Processing Record 114 | Riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=riyadh
# City not found. Skipping...
# Processing Record 115 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=geraldton
# Processing Record 116 | Seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=seoul
# Processing Record 117 | Plouzane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=plouzane
# Processing Record 118 | Inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=inhambane
# Processing Record 119 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=iqaluit
# Processing Record 120 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=atuona
# Processing Record 121 | Chunskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=chunskiy
# Processing Record 122 | Deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=deputatskiy
# Processing Record 123 | Chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=chapais
# Processing Record 124 | Nyurba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=nyurba
# City not found. Skipping...
# Processing Record 125 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=qaanaaq
# Processing Record 126 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=grindavik
# Processing Record 127 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=luderitz
# Processing Record 128 | Bulgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=bulgan
# Processing Record 129 | Kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=kalmunai
# Processing Record 130 | Avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=avera
# City not found. Skipping...
# Processing Record 131 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=san cristobal
# Processing Record 132 | Isla Vista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=isla vista
# Processing Record 133 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=castro
# Processing Record 134 | Northam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=northam
# Processing Record 135 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=codrington
# Processing Record 136 | Gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=gat
# Processing Record 137 | Kaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=kaka
# Processing Record 138 | Ahmadpur Sial
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=ahmadpur sial
# Processing Record 139 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=bubaque
# Processing Record 140 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=dunedin
# Processing Record 141 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=sao filipe
# Processing Record 142 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=ostrovnoy
# Processing Record 143 | Acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=acapulco
# Processing Record 144 | Oksfjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=oksfjord
# Processing Record 145 | Ampanihy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=ampanihy
# Processing Record 146 | Altay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=altay
# Processing Record 147 | Port Hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=port hardy
# Processing Record 148 | Morondava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=morondava
# Processing Record 149 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=saint-philippe
# Processing Record 150 | Nadym
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=nadym
# Processing Record 151 | Grand Gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=grand gaube
# Processing Record 152 | Aasiaat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=aasiaat
# Processing Record 153 | Horn Lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=horn lake
# Processing Record 154 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=mount gambier
# Processing Record 155 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=esperance
# Processing Record 156 | High Level
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=high level
# City not found. Skipping...
# Processing Record 157 | Police
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=police
# Processing Record 158 | Jitotol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=jitotol
# Processing Record 159 | San Jeronimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=san jeronimo
# Processing Record 160 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=butaritari
# Processing Record 161 | Aracoiaba da Serra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=aracoiaba da serra
# Processing Record 162 | Borzya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=borzya
# Processing Record 163 | Gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=gamba
# Processing Record 164 | Cairns
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=cairns
# Processing Record 165 | Nara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=nara
# Processing Record 166 | Poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=poum
# Processing Record 167 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=kavaratti
# Processing Record 168 | Tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=tura
# Processing Record 169 | Caceres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=caceres
# Processing Record 170 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=chuy
# Processing Record 171 | Cavarzere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=cavarzere
# Processing Record 172 | Cefalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=cefalu
# Processing Record 173 | Gorontalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=gorontalo
# Processing Record 174 | Shiyan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=shiyan
# Processing Record 175 | Dali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=dali
# Processing Record 176 | Kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=kloulklubed
# Processing Record 177 | Kamyshevatskaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=kamyshevatskaya
# Processing Record 178 | Khandbari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=khandbari
# Processing Record 179 | Takhtamygda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=takhtamygda
# Processing Record 180 | Kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=kieta
# Processing Record 181 | Humaita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=humaita
# Processing Record 182 | Margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=margate
# Processing Record 183 | Hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=hualmay
# Processing Record 184 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=chokurdakh
# Processing Record 185 | Nerchinskiy Zavod
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=nerchinskiy zavod
# City not found. Skipping...
# Processing Record 186 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=hambantota
# Processing Record 187 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=thompson
# Processing Record 188 | Tazovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=tazovskiy
# Processing Record 189 | Praya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=praya
# Processing Record 190 | Wanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=wanning
# Processing Record 191 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=severo-kurilsk
# Processing Record 192 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=provideniya
# Processing Record 193 | Angoche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=angoche
# Processing Record 194 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=constitucion
# Processing Record 195 | Mgachi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=mgachi
# Processing Record 196 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=nikolskoye
# Processing Record 197 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=tuatapere
# Processing Record 198 | Sergeyevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=sergeyevka
# Processing Record 199 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=hasaki
# Processing Record 200 | Rome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=roma
# Processing Record 201 | Strezhevoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=strezhevoy
# Processing Record 202 | Shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=shingu
# Processing Record 203 | Broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=broome
# Processing Record 204 | Barcelos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=barcelos
# Processing Record 205 | Rijeka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=rijeka
# Processing Record 206 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=kahului
# Processing Record 207 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=ponta do sol
# Processing Record 208 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=port blair
# Processing Record 209 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=ribeira grande
# City not found. Skipping...
# Processing Record 210 | Hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=hami
# Processing Record 211 | Atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=atar
# Processing Record 212 | North Bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=north bend
# Processing Record 213 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=lorengau
# Processing Record 214 | Portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=portland
# Processing Record 215 | Oktyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=oktyabrskiy
# Processing Record 216 | Soyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=soyo
# Processing Record 217 | Kolyvan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=kolyvan
# Processing Record 218 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=victoria
# Processing Record 219 | Dedougou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=dedougou
# Processing Record 220 | Muli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=muli
# Processing Record 221 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=saldanha
# Processing Record 222 | Taunggyi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=taunggyi
# Processing Record 223 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=caravelas
# Processing Record 224 | Jining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=jining
# City not found. Skipping...
# Processing Record 225 | Ahuimanu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=ahuimanu
# Processing Record 226 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=port elizabeth
# Processing Record 227 | Redlands
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=redlands
# Processing Record 228 | Loandjili
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=loandjili
# Processing Record 229 | Champagnole
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=champagnole
# Processing Record 230 | Sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=sinnamary
# Processing Record 231 | Maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=maniitsoq
# City not found. Skipping...
# Processing Record 232 | Poole
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=poole
# Processing Record 233 | Prince Rupert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=prince rupert
# Processing Record 234 | Havre-Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=havre-saint-pierre
# Processing Record 235 | Kisangani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=kisangani
# Processing Record 236 | Shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=shimoda
# Processing Record 237 | Charleston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=charleston
# Processing Record 238 | Opuwo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=opuwo
# Processing Record 239 | Bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=bilma
# Processing Record 240 | Ekhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=ekhabi
# Processing Record 241 | Sabha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=sabha
# Processing Record 242 | Tomatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=tomatlan
# Processing Record 243 | Rio Gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=rio gallegos
# Processing Record 244 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=cherskiy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 245 | Pringsewu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=pringsewu
# Processing Record 246 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=sitka
# Processing Record 247 | Huilong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=huilong
# Processing Record 248 | Marsa Matruh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=marsa matruh
# Processing Record 249 | Yanam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=yanam
# Processing Record 250 | Aswan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=aswan
# Processing Record 251 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=bethel
# Processing Record 252 | Montepuez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=montepuez
# Processing Record 253 | Meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=meulaboh
# Processing Record 254 | Mecca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=mecca
# City not found. Skipping...
# Processing Record 255 | Nushki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=nushki
# Processing Record 256 | Sibolga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=sibolga
# Processing Record 257 | Wyndham
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=wyndham
# Processing Record 258 | Sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=sur
# Processing Record 259 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=norman wells
# Processing Record 260 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=talnakh
# Processing Record 261 | Kologriv
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=kologriv
# Processing Record 262 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=longyearbyen
# Processing Record 263 | Wagar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=wagar
# Processing Record 264 | Juneau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=juneau
# Processing Record 265 | Chichli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=chichli
# Processing Record 266 | Berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=berlevag
# Processing Record 267 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=kapaa
# Processing Record 268 | Novopavlovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=novopavlovka
# Processing Record 269 | Talaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=talaya
# Processing Record 270 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=srednekolymsk
# Processing Record 271 | Pritzwalk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=pritzwalk
# Processing Record 272 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=upernavik
# Processing Record 273 | Arraias
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=arraias
# Processing Record 274 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=guerrero negro
# Processing Record 275 | Mingguang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=mingguang
# Processing Record 276 | Kabwe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=kabwe
# Processing Record 277 | Tikrit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=tikrit
# Processing Record 278 | Hanstholm
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=hanstholm
# Processing Record 279 | Morant Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=morant bay
# Processing Record 280 | Champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=champerico
# Processing Record 281 | Coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=coihaique
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 282 | Povoa de Santa Iria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=povoa de santa iria
# Processing Record 283 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=coquimbo
# Processing Record 284 | Nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=nome
# Processing Record 285 | Muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=muros
# Processing Record 286 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=mehamn
# Processing Record 287 | Kyzyl-Suu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=kyzyl-suu
# Processing Record 288 | Padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=padang
# City not found. Skipping...
# Processing Record 289 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=clyde river
# Processing Record 290 | Darhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=darhan
# Processing Record 291 | Madingou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=madingou
# Processing Record 292 | Hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=hobyo
# Processing Record 293 | Melfort
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=melfort
# Processing Record 294 | Kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=kangaatsiaq
# Processing Record 295 | Neiafu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=neiafu
# Processing Record 296 | Karasuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=karasuk
# Processing Record 297 | Porangatu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=porangatu
# City not found. Skipping...
# Processing Record 298 | Jamame
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=jamame
# Processing Record 299 | Mayor Pablo Lagerenza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=mayor pablo lagerenza
# Processing Record 300 | Saint Lawrence
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=san lawrenz
# Processing Record 301 | Ondjiva
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=ondjiva
# Processing Record 302 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=pisco
# City not found. Skipping...
# Processing Record 303 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=ahipara
# Processing Record 304 | Marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=marawi
# Processing Record 305 | Yarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=yarmouth
# Processing Record 306 | Karaton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=karaton
# Processing Record 307 | Carauari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=carauari
# Processing Record 308 | Laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=laguna
# Processing Record 309 | Tarakan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=tarakan
# City not found. Skipping...
# Processing Record 310 | Qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=qaqortoq
# Processing Record 311 | Darnah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=darnah
# Processing Record 312 | Salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=salinopolis
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 313 | Haifa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=haifa
# Processing Record 314 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=ilulissat
# Processing Record 315 | Cukai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=cukai
# Processing Record 316 | Penzance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=penzance
# Processing Record 317 | Sosnovo-Ozerskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=sosnovo-ozerskoye
# Processing Record 318 | Palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=palmer
# Processing Record 319 | Manaus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=manaus
# Processing Record 320 | Wanaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=wanaka
# Processing Record 321 | Hovd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=hovd
# Processing Record 322 | Sibi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=sibi
# Processing Record 323 | Haines Junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=haines junction
# Processing Record 324 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=klaksvik
# Processing Record 325 | Trinidad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=trinidad
# Processing Record 326 | Vikhorevka
# ...
# City not found. Skipping...
# Processing Record 472 | Pachino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=pachino
# Processing Record 473 | Inirida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=inirida
# Processing Record 474 | Kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=kununurra
# Processing Record 475 | Bud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=bud
# Processing Record 476 | Denpasar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=denpasar
# City not found. Skipping...
# Processing Record 477 | Manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=manokwari
# Processing Record 478 | Muncar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=muncar
# Processing Record 479 | Liwale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=liwale
# Processing Record 480 | Saint-Louis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=saint-louis
# Processing Record 481 | Lobva
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=lobva
# Processing Record 482 | Ust-Nera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=ust-nera
# City not found. Skipping...
# Processing Record 483 | Fort Frances
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=fort frances
# Processing Record 484 | Pocone
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=pocone
# Processing Record 485 | Agadez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=agadez
# Processing Record 486 | Sibut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=sibut
# Processing Record 487 | Birin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=birin
# Processing Record 488 | Beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=beringovskiy
# Processing Record 489 | Sakaiminato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=sakaiminato
# Processing Record 490 | Vidim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=vidim
# Processing Record 491 | Kilimatinde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=kilimatinde
# Processing Record 492 | Prien
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=prien
# Processing Record 493 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=saint george
# Processing Record 494 | Half Moon Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=half moon bay
# Processing Record 495 | Asosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=asosa
# Processing Record 496 | Madera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=madera
# Processing Record 497 | Maykor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=maykor
# Processing Record 498 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=aklavik
# Processing Record 499 | Jinji
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=jinji
# Processing Record 500 | Visby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=visby
# City not found. Skipping...
# Processing Record 501 | Ramon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=ramon
# Processing Record 502 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=port lincoln
# Processing Record 503 | Waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=waingapu
# Processing Record 504 | Gunjur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=gunjur
# Processing Record 505 | Brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=brae
# Processing Record 506 | Imbituba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=imbituba
# Processing Record 507 | Port Hawkesbury
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=port hawkesbury
# City not found. Skipping...
# Processing Record 508 | Naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=naze
# Processing Record 509 | Ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=ballina
# Processing Record 510 | Tamna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=tamna
# Processing Record 511 | Patiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=patiya
# Processing Record 512 | Urla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=urla
# Processing Record 513 | Port-Gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=port-gentil
# City not found. Skipping...
# Processing Record 514 | Almaznyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=almaznyy
# Processing Record 515 | Bodinayakkanur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=bodinayakkanur
# Processing Record 516 | Kungurtug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=kungurtug
# Processing Record 517 | Itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=itarema
# Processing Record 518 | Kampong Chhnang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=kampong chhnang
# Processing Record 519 | Lavumisa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=lavumisa
# Processing Record 520 | Magistralnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=magistralnyy
# Processing Record 521 | Neyshabur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=neyshabur
# Processing Record 522 | Elizabeth City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=elizabeth city
# Processing Record 523 | Lykhivka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=lykhivka
# City not found. Skipping...
# Processing Record 524 | Bahia Blanca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=bahia blanca
# Processing Record 525 | Tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=tautira
# City not found. Skipping...
# Processing Record 526 | San Pedro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=san pedro
# Processing Record 527 | Kimbe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=kimbe
# Processing Record 528 | Tucupita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=tucupita
# Processing Record 529 | Alto Araguaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=alto araguaia
# Processing Record 530 | Mocuba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=mocuba
# Processing Record 531 | Husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=husavik
# City not found. Skipping...
# Processing Record 532 | Ulety
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=ulety
# Processing Record 533 | Vavuniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=vavuniya
# Processing Record 534 | Lucea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=lucea
# Processing Record 535 | Luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=luanda
# Processing Record 536 | Abu Samrah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=abu samrah
# Processing Record 537 | Meadow Lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=meadow lake
# Processing Record 538 | Atikokan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=atikokan
# Processing Record 539 | Sungairaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=sungairaya
# Processing Record 540 | Talcahuano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=talcahuano
# Processing Record 541 | Dom Pedrito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=dom pedrito
# Processing Record 542 | Khandela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=khandela
# Processing Record 543 | Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=alfred
# Processing Record 544 | Fremont
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=fremont
# City not found. Skipping...
# Processing Record 545 | Port Pirie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=port pirie
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 546 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=lavrentiya
# Processing Record 547 | Senhor do Bonfim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=senhor do bonfim
# Processing Record 548 | Rafraf
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=rafraf
# Processing Record 549 | Takaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=takaka
# Processing Record 550 | Iquitos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=iquitos
# Processing Record 551 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=alofi
# Processing Record 552 | Lokosovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=lokosovo
# Processing Record 553 | Constantine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=constantine
# Processing Record 554 | Lakes Entrance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=lakes entrance
# Processing Record 555 | Suriapet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=suriapet
# City not found. Skipping...
# Processing Record 556 | Trelew
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=trelew
# Processing Record 557 | Erenhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=erenhot
# Processing Record 558 | Guabito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=guabito
# Processing Record 559 | Divo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=divo
# Processing Record 560 | Nanae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=nanae
# Processing Record 561 | Zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=zyryanka
# Processing Record 562 | Hornepayne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=hornepayne
# Processing Record 563 | Farafangana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=farafangana
# Processing Record 564 | Caronport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=caronport
# City not found. Skipping...
# Processing Record 565 | Moose Jaw
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=moose jaw
# City not found. Skipping...
# Processing Record 566 | Bone
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=bone
# Processing Record 567 | Emerald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=emerald
# Processing Record 568 | Karpathos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=karpathos
# Processing Record 569 | Port Hueneme
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=port hueneme
# City not found. Skipping...
# Processing Record 570 | Tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=tilichiki
# Processing Record 571 | Shakawe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=shakawe
# Processing Record 572 | Ponta Delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=ponta delgada
# Processing Record 573 | Nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=nuuk
# Processing Record 574 | Novoagansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=novoagansk
# Processing Record 575 | Daram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=daram
# Processing Record 576 | Devrek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=devrek
# City not found. Skipping...
# Processing Record 577 | Egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e587430106db6c8ed1fe8e4347e8bf2&q=egvekinot
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
weather_col = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}


weather_data = pd.DataFrame(weather_col)


weather_data.count()
# Out:
# City          577
# Cloudiness    577
# Country       577
# Date          577
# Humidity      577
# Lat           577
# Lng           577
# Max Temp      577
# Wind Speed    577
# dtype: int64

# %%
weather_data.to_csv('weather_data.csv')

weather_data.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      Hermanus          69      ZA  1562866675        94 -34.42   19.24
# 1    Georgetown          75      GY  1562866676        83   6.80  -58.16
# 2        Barrow         100      AR  1562866678        59 -38.31  -60.23
# 3        Nabire         100      ID  1562866679        97  -3.36  135.50
# 4  Port Alberni          40      CA  1562866680        72  49.24 -124.81
#
#    Max Temp  Wind Speed
# 0     59.00        1.01
# 1     86.00        6.93
# 2     58.89        0.96
# 3     67.89        4.38
# 4     68.00        6.93

# %%
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)


plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)


plt.savefig("Max_Temp_vs_Latitude.png")

plt.show()

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)


plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)


plt.savefig("Humidity_vs_Latitude.png")


plt.show()

# %%
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)


plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)


plt.savefig("Cloudiness_vs_Latitude.png")


plt.show()

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)


plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)


plt.savefig("Wind Speed_vs_Latitude.png")


plt.show()
