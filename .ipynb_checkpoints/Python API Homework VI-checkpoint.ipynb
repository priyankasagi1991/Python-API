# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from api_keys import api_key



from citipy import citipy


output_data_file = "cities.csv"


lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
lat_lngs = []
cities = []


lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)


for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
  
    if city not in cities:
        cities.append(city)


len(cities)
# Out:
# 628

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []


record = 1


print(f"Beginning Data Retrieval")
print(f"-------------------------------")


for city in cities:  
    
    
  
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        
        
        
        record= record + 1
        
        
        time.sleep(1.01)
        
  
    except:
        print("City not found. Skipping...")
    continue
 
print(f"-------------------------------")
print(f"Data Retrieval Complete")
print(f"-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# City not found. Skipping...
# Processing Record 1 | Punta Arenas
# Processing Record 2 | Mukdahan
# Processing Record 3 | Calabozo
# Processing Record 4 | Brigham City
# Processing Record 5 | Nyazepetrovsk
# Processing Record 6 | Upernavik
# Processing Record 7 | Tadine
# Processing Record 8 | Kruisfontein
# Processing Record 9 | Aksu
# Processing Record 10 | Chokurdakh
# Processing Record 11 | Carnarvon
# Processing Record 12 | Yellowknife
# Processing Record 13 | Geraldton
# City not found. Skipping...
# Processing Record 14 | Gulf Gate Estates
# Processing Record 15 | Souillac
# Processing Record 16 | Ribeira Grande
# Processing Record 17 | Moree
# Processing Record 18 | Saint-Philippe
# Processing Record 19 | Ciudad Bolivar
# Processing Record 20 | Teguldet
# Processing Record 21 | Kapaa
# Processing Record 22 | Dolores
# Processing Record 23 | Rikitea
# Processing Record 24 | Ushuaia
# Processing Record 25 | Grindavik
# Processing Record 26 | Shipunovo
# Processing Record 27 | Jamestown
# Processing Record 28 | Albany
# Processing Record 29 | Codrington
# Processing Record 30 | Qaqortoq
# Processing Record 31 | Port Elizabeth
# Processing Record 32 | Roald
# Processing Record 33 | Busselton
# Processing Record 34 | Lavrentiya
# Processing Record 35 | Stockholm
# Processing Record 36 | Tiksi
# Processing Record 37 | Mataura
# Processing Record 38 | Los Llanos de Aridane
# City not found. Skipping...
# Processing Record 39 | Ahipara
# Processing Record 40 | Tessalit
# Processing Record 41 | Kaduna
# Processing Record 42 | Port Blair
# Processing Record 43 | New Norfolk
# Processing Record 44 | Boa Vista
# Processing Record 45 | Lompoc
# Processing Record 46 | Gornyy
# Processing Record 47 | Kosino
# Processing Record 48 | Aklavik
# Processing Record 49 | Qaanaaq
# Processing Record 50 | San Jose
# Processing Record 51 | Saskylakh
# Processing Record 52 | Atuona
# City not found. Skipping...
# Processing Record 53 | Almaznyy
# Processing Record 54 | Vaini
# Processing Record 55 | Cabo San Lucas
# Processing Record 56 | Longyearbyen
# Processing Record 57 | Hilo
# Processing Record 58 | Lata
# Processing Record 59 | Bambous Virieux
# Processing Record 60 | Cabedelo
# Processing Record 61 | Kaitangata
# Processing Record 62 | Mar del Plata
# Processing Record 63 | Kawalu
# Processing Record 64 | Vanavara
# Processing Record 65 | Kodiak
# Processing Record 66 | Hofn
# Processing Record 67 | Omboue
# Processing Record 68 | Yarada
# Processing Record 69 | Kununurra
# Processing Record 70 | Praia da Vitoria
# Processing Record 71 | Torata
# Processing Record 72 | Thompson
# Processing Record 73 | Paamiut
# Processing Record 74 | Bredasdorp
# Processing Record 75 | Honiara
# Processing Record 76 | Seville
# Processing Record 77 | Shihezi
# Processing Record 78 | De Aar
# Processing Record 79 | Moron
# Processing Record 80 | Luangwa
# Processing Record 81 | Dingle
# Processing Record 82 | Biltine
# Processing Record 83 | Faanui
# Processing Record 84 | Kochevo
# Processing Record 85 | Mahebourg
# Processing Record 86 | Fort Abbas
# Processing Record 87 | Pangnirtung
# Processing Record 88 | Husavik
# Processing Record 89 | Puerto Ayora
# Processing Record 90 | Manzhouli
# Processing Record 91 | Vila Velha
# Processing Record 92 | Labuhan
# Processing Record 93 | Port Alfred
# City not found. Skipping...
# Processing Record 94 | Chuy
# City not found. Skipping...
# Processing Record 95 | Ushtobe
# Processing Record 96 | Iqaluit
# Processing Record 97 | Beringovskiy
# Processing Record 98 | Cape Town
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 99 | Dikson
# Processing Record 100 | Nicoya
# Processing Record 101 | Arman
# Processing Record 102 | Cabrero
# City not found. Skipping...
# Processing Record 103 | Alta Floresta
# Processing Record 104 | Morinville
# Processing Record 105 | Vaitape
# Processing Record 106 | Miri
# Processing Record 107 | Vao
# Processing Record 108 | Grande Prairie
# Processing Record 109 | Ilulissat
# Processing Record 110 | Constitucion
# Processing Record 111 | Flinders
# Processing Record 112 | Butaritari
# City not found. Skipping...
# Processing Record 113 | Tautira
# Processing Record 114 | Khor
# Processing Record 115 | Cidreira
# Processing Record 116 | Torbay
# City not found. Skipping...
# Processing Record 117 | Nikolskoye
# Processing Record 118 | San Patricio
# Processing Record 119 | Hithadhoo
# Processing Record 120 | Warrnambool
# Processing Record 121 | Eyl
# Processing Record 122 | Shenjiamen
# Processing Record 123 | El Alto
# Processing Record 124 | Srednekolymsk
# Processing Record 125 | Bilibino
# City not found. Skipping...
# Processing Record 126 | Jilin
# Processing Record 127 | Ewa Beach
# Processing Record 128 | Port Hedland
# Processing Record 129 | Mingaora
# Processing Record 130 | East London
# Processing Record 131 | Naantali
# Processing Record 132 | Mahon
# Processing Record 133 | Sulangan
# Processing Record 134 | Bluff
# Processing Record 135 | Bethel
# Processing Record 136 | Kingman
# Processing Record 137 | Buzmeyin
# Processing Record 138 | Anadyr
# Processing Record 139 | Shawville
# Processing Record 140 | Vilyuysk
# City not found. Skipping...
# Processing Record 141 | Hasaki
# Processing Record 142 | Ampanihy
# Processing Record 143 | Airai
# Processing Record 144 | Ponta do Sol
# Processing Record 145 | Jacareacanga
# City not found. Skipping...
# Processing Record 146 | Hami
# Processing Record 147 | Isiolo
# Processing Record 148 | Haapiti
# Processing Record 149 | Oistins
# Processing Record 150 | Bertinoro
# Processing Record 151 | Brownwood
# Processing Record 152 | Hermanus
# City not found. Skipping...
# Processing Record 153 | Ancud
# Processing Record 154 | Adrar
# Processing Record 155 | Gilgit
# Processing Record 156 | Shingu
# Processing Record 157 | Alexandria
# Processing Record 158 | Dudinka
# Processing Record 159 | Arraial do Cabo
# Processing Record 160 | Balikpapan
# Processing Record 161 | Nanortalik
# Processing Record 162 | Nishihara
# Processing Record 163 | Onega
# Processing Record 164 | Gidole
# Processing Record 165 | Lebu
# Processing Record 166 | Zhaotong
# Processing Record 167 | Batuan
# Processing Record 168 | Micheweni
# City not found. Skipping...
# Processing Record 169 | Alzamay
# Processing Record 170 | Khatanga
# City not found. Skipping...
# Processing Record 171 | Avera
# Processing Record 172 | Namibe
# Processing Record 173 | Cobija
# Processing Record 174 | Oranjemund
# Processing Record 175 | Vila Franca do Campo
# Processing Record 176 | Pangai
# Processing Record 177 | Sabha
# Processing Record 178 | Shieli
# Processing Record 179 | Pisco
# City not found. Skipping...
# Processing Record 180 | Kisangani
# Processing Record 181 | Phulji
# Processing Record 182 | Hobart
# Processing Record 183 | Eirunepe
# Processing Record 184 | Misratah
# Processing Record 185 | Chimbote
# Processing Record 186 | Yulara
# Processing Record 187 | Muros
# Processing Record 188 | Buala
# Processing Record 189 | Avarua
# Processing Record 190 | Churapcha
# Processing Record 191 | Acapulco
# Processing Record 192 | Quimperle
# Processing Record 193 | Shimoda
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 194 | Sisimiut
# Processing Record 195 | Biggar
# Processing Record 196 | Cururupu
# Processing Record 197 | Bathsheba
# Processing Record 198 | Irondequoit
# Processing Record 199 | Coihaique
# Processing Record 200 | Tuktoyaktuk
# Processing Record 201 | Casablanca
# Processing Record 202 | Prince Rupert
# Processing Record 203 | Laguna
# Processing Record 204 | Palmer
# Processing Record 205 | Yumen
# Processing Record 206 | Talnakh
# Processing Record 207 | Charters Towers
# City not found. Skipping...
# Processing Record 208 | Djibo
# Processing Record 209 | Kirakira
# Processing Record 210 | Southern Pines
# Processing Record 211 | Mashhad
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 212 | La Paz
# Processing Record 213 | Barrow
# Processing Record 214 | Fermoy
# Processing Record 215 | Faya
# City not found. Skipping...
# Processing Record 216 | Rio Gallegos
# Processing Record 217 | Sainte-Marie
# Processing Record 218 | Mbandaka
# Processing Record 219 | Great Yarmouth
# Processing Record 220 | Kozhva
# City not found. Skipping...
# Processing Record 221 | Ranau
# Processing Record 222 | Jiangyou
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 223 | Tasiilaq
# Processing Record 224 | Iberia
# Processing Record 225 | Castro
# Processing Record 226 | Antibes
# City not found. Skipping...
# Processing Record 227 | Bulungu
# Processing Record 228 | Kastamonu
# Processing Record 229 | Lucapa
# Processing Record 230 | Amapa
# Processing Record 231 | Zaranj
# Processing Record 232 | Santa Cruz de las Flores
# Processing Record 233 | Richmond Hill
# Processing Record 234 | Poronaysk
# Processing Record 235 | Ostrovnoy
# Processing Record 236 | Turbat
# Processing Record 237 | Cherskiy
# Processing Record 238 | Freeport
# Processing Record 239 | Rivers
# Processing Record 240 | Rawson
# Processing Record 241 | Naze
# Processing Record 242 | Vedasandur
# Processing Record 243 | Coquimbo
# Processing Record 244 | Norman Wells
# Processing Record 245 | Siderno
# Processing Record 246 | Morondava
# Processing Record 247 | Te Anau
# Processing Record 248 | Kahului
# Processing Record 249 | Tutoia
# Processing Record 250 | Hambantota
# Processing Record 251 | Kalamaria
# Processing Record 252 | Wahpeton
# Processing Record 253 | Portland
# Processing Record 254 | Saldanha
# Processing Record 255 | Vulcanesti
# Processing Record 256 | Pimentel
# Processing Record 257 | Kavaratti
# Processing Record 258 | Aleksandrov Gay
# Processing Record 259 | Porto Novo
# Processing Record 260 | Along
# Processing Record 261 | Gornopravdinsk
# Processing Record 262 | Maltahohe
# City not found. Skipping...
# Processing Record 263 | Krasnorechenskiy
# Processing Record 264 | Guiratinga
# Processing Record 265 | Savannah Bight
# Processing Record 266 | Kandrian
# Processing Record 267 | Miraflores
# Processing Record 268 | Okhotsk
# Processing Record 269 | Road Town
# City not found. Skipping...
# Processing Record 270 | Bowen
# Processing Record 271 | Luderitz
# Processing Record 272 | Hermiston
# Processing Record 273 | Tuatapere
# City not found. Skipping...
# Processing Record 274 | Mandan
# Processing Record 275 | Grahamstown
# Processing Record 276 | Krasnoarmeyskoye
# Processing Record 277 | Caravelas
# Processing Record 278 | Koryukivka
# Processing Record 279 | Klaksvik
# Processing Record 280 | Alyangula
# Processing Record 281 | Magadan
# Processing Record 282 | Bad Frankenhausen
# Processing Record 283 | Kalmunai
# Processing Record 284 | Goderich
# Processing Record 285 | Atasu
# Processing Record 286 | Georgetown
# Processing Record 287 | Celestun
# Processing Record 288 | Sao Joao da Barra
# Processing Record 289 | Clyde River
# Processing Record 290 | Ballina
# City not found. Skipping...
# Processing Record 291 | Bilma
# Processing Record 292 | Kyren
# Processing Record 293 | Ust-Nera
# Processing Record 294 | Macau
# City not found. Skipping...
# Processing Record 295 | Nynashamn
# Processing Record 296 | Malangali
# City not found. Skipping...
# Processing Record 297 | Bongandanga
# Processing Record 298 | Dongying
# Processing Record 299 | Severo-Kurilsk
# Processing Record 300 | Tilichiki
# Processing Record 301 | Port Lincoln
# Processing Record 302 | Hyeres
# Processing Record 303 | Sao Filipe
# Processing Record 304 | Provideniya
# Processing Record 305 | Bogorodskoye
# Processing Record 306 | Pitimbu
# Processing Record 307 | Pyaozerskiy
# Processing Record 308 | Iisalmi
# Processing Record 309 | Antofagasta
# Processing Record 310 | Tateyama
# Processing Record 311 | College
# Processing Record 312 | Sarangani
# Processing Record 313 | Bonavista
# Processing Record 314 | Henties Bay
# Processing Record 315 | High Level
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 316 | Marsh Harbour
# Processing Record 317 | Port Keats
# Processing Record 318 | Belyy Yar
# Processing Record 319 | Aksarka
# Processing Record 320 | Neiafu
# Processing Record 321 | Fortuna
# Processing Record 322 | Tomatlan
# Processing Record 323 | Gazanjyk
# Processing Record 324 | Ketchikan
# Processing Record 325 | Samarai
# Processing Record 326 | Iskateley
# Processing Record 327 | Kaohsiung
# Processing Record 328 | Nyurba
# Processing Record 329 | Anchorage
# Processing Record 330 | Fomboni
# Processing Record 331 | Guerrero Negro
# Processing Record 332 | Taoudenni
# Processing Record 333 | Pacific Grove
# Processing Record 334 | Nago
# Processing Record 335 | Le Port
# Processing Record 336 | Esperance
# Processing Record 337 | Tura
# Processing Record 338 | Deogarh
# Processing Record 339 | Eureka
# Processing Record 340 | Comodoro Rivadavia
# Processing Record 341 | Salinopolis
# Processing Record 342 | Alcazar de San Juan
# Processing Record 343 | Raha
# Processing Record 344 | Itacoatiara
# City not found. Skipping...
# Processing Record 345 | Clarence Town
# Processing Record 346 | Bay-Khaak
# Processing Record 347 | Kattivakkam
# Processing Record 348 | Taksimo
# Processing Record 349 | Calama
# Processing Record 350 | Taltal
# Processing Record 351 | Keetmanshoop
# Processing Record 352 | Bahia Blanca
# Processing Record 353 | Elizabeth City
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 354 | Saint George
# Processing Record 355 | Montrose
# City not found. Skipping...
# Processing Record 356 | Biloela
# Processing Record 357 | Korop
# Processing Record 358 | Changying
# Processing Record 359 | Sussex
# Processing Record 360 | Gamba
# Processing Record 361 | Hailar
# Processing Record 362 | Aitape
# Processing Record 363 | Dzhebariki-Khaya
# Processing Record 364 | Cangzhou
# Processing Record 365 | Bosaso
# Processing Record 366 | Matay
# Processing Record 367 | Lagoa
# Processing Record 368 | Benguela
# Processing Record 369 | Poya
# Processing Record 370 | Macon
# Processing Record 371 | Roanoke Rapids
# Processing Record 372 | Oktyabrskiy
# Processing Record 373 | Isangel
# Processing Record 374 | Whitehorse
# Processing Record 375 | Herat
# Processing Record 376 | Torres
# Processing Record 377 | Opuwo
# Processing Record 378 | Sibolga
# Processing Record 379 | Paldiski
# Processing Record 380 | Necochea
# Processing Record 381 | Beyneu
# Processing Record 382 | Muskegon
# Processing Record 383 | Grand Gaube
# Processing Record 384 | Leshukonskoye
# City not found. Skipping...
# Processing Record 385 | Salinas
# Processing Record 386 | Nagato
# Processing Record 387 | Grand-Lahou
# Processing Record 388 | Richards Bay
# Processing Record 389 | Ormara
# Processing Record 390 | Maldonado
# Processing Record 391 | Nelson Bay
# Processing Record 392 | Premia de Mar
# Processing Record 393 | Skegness
# Processing Record 394 | Gondanglegi
# Processing Record 395 | Carnot
# Processing Record 396 | Baixa Grande
# Processing Record 397 | Rancho Palos Verdes
# Processing Record 398 | Kumta
# Processing Record 399 | Sioux Lookout
# Processing Record 400 | Kudymkar
# Processing Record 401 | Stryn
# City not found. Skipping...
# Processing Record 402 | Pevek
# Processing Record 403 | Katherine
# Processing Record 404 | Coro
# Processing Record 405 | Zhob
# City not found. Skipping...
# Processing Record 406 | Saint-Louis
# Processing Record 407 | Nioro
# Processing Record 408 | Davila
# Processing Record 409 | Mangrol
# Processing Record 410 | Nizhneangarsk
# Processing Record 411 | Sitka
# Processing Record 412 | Mazara del Vallo
# Processing Record 413 | Banepa
# Processing Record 414 | Luyang
# Processing Record 415 | Yabelo
# City not found. Skipping...
# Processing Record 416 | Kendari
# Processing Record 417 | Madimba
# Processing Record 418 | Karratha
# Processing Record 419 | Nalut
# Processing Record 420 | Alofi
# Processing Record 421 | Cap Malheureux
# Processing Record 422 | Diamantino
# Processing Record 423 | Mayor Pablo Lagerenza
# Processing Record 424 | Broome
# Processing Record 425 | Virginia
# Processing Record 426 | Baraboo
# Processing Record 427 | Bara
# Processing Record 428 | Buin
# Processing Record 429 | Key Largo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 430 | Chulman
# Processing Record 431 | Mumford
# Processing Record 432 | Hirara
# Processing Record 433 | Uinskoye
# Processing Record 434 | Kaabong
# Processing Record 435 | Maumere
# Processing Record 436 | Gotsu
# Processing Record 437 | Riwaka
# Processing Record 438 | Nome
# Processing Record 439 | Kashin
# Processing Record 440 | Banjar
# Processing Record 441 | Poum
# City not found. Skipping...
# Processing Record 442 | Ashtian
# Processing Record 443 | Goldsboro
# Processing Record 444 | Bichena
# Processing Record 445 | Salalah
# Processing Record 446 | Aasiaat
# City not found. Skipping...
# Processing Record 447 | Maniitsoq
# Processing Record 448 | Griffith
# Processing Record 449 | Turukhansk
# City not found. Skipping...
# Processing Record 450 | Sungaipenuh
# Processing Record 451 | Sawtell
# City not found. Skipping...
# Processing Record 452 | Canyon Lake
# Processing Record 453 | Asosa
# Processing Record 454 | Lazaro Cardenas
# City not found. Skipping...
# Processing Record 455 | San Cristobal
# Processing Record 456 | Hastings
# Processing Record 457 | Victoria
# Processing Record 458 | Mecca
# Processing Record 459 | Atar
# Processing Record 460 | Namatanai
# Processing Record 461 | Nacala
# Processing Record 462 | Le Moule
# Processing Record 463 | Santa Cruz del Sur
# Processing Record 464 | Thaton
# Processing Record 465 | Kamaishi
# Processing Record 466 | Doha
# Processing Record 467 | Skjervoy
# Processing Record 468 | Sibu
# Processing Record 469 | Washington DC.
# City not found. Skipping...
# Processing Record 470 | Wakkanai
# Processing Record 471 | Sar-e Pul
# City not found. Skipping...
# Processing Record 472 | Pedasi
# Processing Record 473 | Tezu
# Processing Record 474 | Klyuchi
# City not found. Skipping...
# Processing Record 475 | Bristol
# Processing Record 476 | Yenagoa
# Processing Record 477 | Montepuez
# Processing Record 478 | Teya
# Processing Record 479 | Manicore
# Processing Record 480 | Monrovia
# Processing Record 481 | Gigmoto
# Processing Record 482 | Narsaq
# Processing Record 483 | Novikovo
# Processing Record 484 | Conakry
# Processing Record 485 | Christchurch
# Processing Record 486 | Koulikoro
# Processing Record 487 | Kimbe
# Processing Record 488 | Berlevag
# Processing Record 489 | Batemans Bay
# Processing Record 490 | Darnah
# Processing Record 491 | Grimstad
# Processing Record 492 | Mandera
# Processing Record 493 | Taybad
# Processing Record 494 | Ratnagiri
# Processing Record 495 | Chongwe
# City not found. Skipping...
# Processing Record 496 | Vardo
# Processing Record 497 | Kiama
# Processing Record 498 | Dongfeng
# Processing Record 499 | Felipe Carrillo Puerto
# Processing Record 500 | Soc Trang
# Processing Record 501 | Pandan
# Processing Record 502 | Axim
# City not found. Skipping...
# Processing Record 503 | Auki
# Processing Record 504 | Tocopilla
# Processing Record 505 | Dhuri
# City not found. Skipping...
# Processing Record 506 | Vysokogornyy
# Processing Record 507 | Bandarbeyla
# Processing Record 508 | Tonekabon
# Processing Record 509 | Preobrazheniye
# Processing Record 510 | Carutapera
# Processing Record 511 | Kupang
# Processing Record 512 | Huarmey
# Processing Record 513 | Lamar
# Processing Record 514 | Pangody
# Processing Record 515 | Maceio
# Processing Record 516 | Berdigestyakh
# City not found. Skipping...
# Processing Record 517 | Sfantu Gheorghe
# Processing Record 518 | Wukari
# City not found. Skipping...
# Processing Record 519 | Nizip
# Processing Record 520 | Rafaela
# Processing Record 521 | Touros
# Processing Record 522 | Fiche
# City not found. Skipping...
# Processing Record 523 | Sharkan
# Processing Record 524 | Zhigansk
# City not found. Skipping...
# Processing Record 525 | Qujing
# Processing Record 526 | Puerto Colombia
# Processing Record 527 | Bereda
# Processing Record 528 | Honningsvag
# Processing Record 529 | Kalianget
# Processing Record 530 | Ponta Delgada
# Processing Record 531 | Leningradskiy
# Processing Record 532 | Marsa Matruh
# Processing Record 533 | Tupiza
# Processing Record 534 | Ahuimanu
# Processing Record 535 | Bichura
# Processing Record 536 | Singaraja
# Processing Record 537 | Mana
# Processing Record 538 | Baykit
# Processing Record 539 | Khandyga
# Processing Record 540 | Ust-Charyshskaya Pristan
# Processing Record 541 | Valparaiso
# Processing Record 542 | Deputatskiy
# Processing Record 543 | Sangar
# Processing Record 544 | Kargasok
# Processing Record 545 | Plettenberg Bay
# Processing Record 546 | Kayerkan
# Processing Record 547 | Kilindoni
# Processing Record 548 | Praid
# City not found. Skipping...
# Processing Record 549 | Namtsy
# Processing Record 550 | Jalu
# Processing Record 551 | Sosnovo-Ozerskoye
# City not found. Skipping...
# Processing Record 552 | Shamary
# Processing Record 553 | Murray Bridge
# Processing Record 554 | Balaipungut
# Processing Record 555 | Mirpur Sakro
# Processing Record 556 | Lexington
# City not found. Skipping...
# Processing Record 557 | Padang
# Processing Record 558 | Belmonte
# Processing Record 559 | Bulolo
# Processing Record 560 | Zabol
# Processing Record 561 | Sorland
# City not found. Skipping...
# Processing Record 562 | Alenquer
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
weather_col = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}


weather_data = pd.DataFrame(weather_col)


weather_data.count()
# Out:
# City          562
# Cloudiness    562
# Country       562
# Date          562
# Humidity      562
# Lat           562
# Lng           562
# Max Temp      562
# Wind Speed    562
# dtype: int64

# %%
weather_data.to_csv('weather_data.csv')

weather_data.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0   Punta Arenas          90      CL  1562874580        93 -53.16  -70.91
# 1       Mukdahan         100      TH  1562874879        89  16.54  104.73
# 2       Calabozo          23      VE  1562874880        72   8.92  -67.43
# 3   Brigham City           1      US  1562874711         8  41.51 -112.02
# 4  Nyazepetrovsk          84      RU  1562874882        95  56.06   59.60
#
#    Max Temp  Wind Speed
# 0     41.00       13.87
# 1     76.89        6.06
# 2     84.81        1.19
# 3     96.01        3.36
# 4     53.85        2.84

# %%
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)


plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)


plt.savefig("Max_Temp_vs_Latitude.png")

plt.show()

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)


plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity(%)")
plt.xlabel("Latitude")
plt.grid(True)


plt.savefig("Humidity_vs_Latitude.png")


plt.show()

# %%
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)


plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness(%)")
plt.xlabel("Latitude")
plt.grid(True)


plt.savefig("Cloudiness_vs_Latitude.png")


plt.show()

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)


plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed(mph)")
plt.xlabel("Latitude")
plt.grid(True)


plt.savefig("Wind Speed_vs_Latitude.png")


plt.show()
